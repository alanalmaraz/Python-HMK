# %%
a = 3
i = 1
f = 1

while(i <= a):
    f = f * i
    i = i + 1

print("El número factorial de " + str(a) + " es: " + str(f))
# Out:
# El número factorial de 3 es: 6

# %% [markdown]
# ![Factorial jupyter.jpg](attachment:5ed30bf8-a59d-4584-a26e-b06a85ee9d3e.jpg)

# %%
a = 97
t = 0
i = 1

while(i <= a):
    if a % i == 0:
        t = t + 1    
    i = i + 1
if t == 2:
    print(str(a) + " es un número primo")
else:
    print(str(a) + " no es un número primo")
# Out:
# 97 es un número primo

# %% [markdown]
# ![Numeros primos jupyter.jpg](attachment:37bdc881-c1f9-4ee6-97c2-381947a2dfac.jpg)
